# %% [markdown]
# <a href="https://colab.research.google.com/github/TKcodes-bit/ML/blob/main/Thomas'_tensorflow_keras_part3_full_pipeline_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to TensorFlow & Keras — Part 3
# ### Training a digit classifier, with experiment tracking
#
# Everything from Parts 1 and 2, put together, with one addition: this
# time every model you train gets logged to **Weights & Biases**, the
# same way your classical ML models were in the Formative. You'll write
# one reusable `log_experiment()` function and reuse it for every
# model below.
#
# ### Code rules for this notebook
# 1. Keep all your imports in the next cell.
# 2. Every model you train must go through `log_experiment()` — don't write a second version of it.
# 3. Give variables names that say what they hold.
# 4. Add type hints to every function you write.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import Any, Dict

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

RANDOM_SEED = 42
tf.random.set_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Step 1: Load the data

# %%
(X_train_raw, y_train), (X_test_raw, y_test) = keras.datasets.mnist.load_data()

print(f"Training images: {X_train_raw.shape}")
print(f"Test images: {X_test_raw.shape}")
print(f"Pixel range: [{X_train_raw.min()}, {X_train_raw.max()}]")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Training images: (60000, 28, 28)
# Test images: (10000, 28, 28)
# Pixel range: [0, 255]

# %% [markdown]
# ## Step 2: Normalize
#
# MNIST pixels are always integers 0-255, so there's no guesswork here
# -- divide by 255 and flatten each image, same as Parts 1 and 2.

# %%
X_train = X_train_raw.reshape(-1, 28 * 28).astype("float32") / 255.0
X_test = X_test_raw.reshape(-1, 28 * 28).astype("float32") / 255.0

print(f"X_train range after normalizing: [{X_train.min()}, {X_train.max()}]")
# Out:
# X_train range after normalizing: [0.0, 1.0]

# %% [markdown]
# ## Step 3: Experiment tracking setup (Weights & Biases)
#
# Set this up **before** training anything, so your baseline run below
# is logged like every run after it.
#
# Store your API key as a Colab secret -- never hardcode it in this
# notebook: left sidebar -> key icon -> add secret named `WANDB_API_KEY`.
#
# This cell is written defensively: if W&B isn't set up yet, the rest
# of the notebook still runs -- you just won't get tracking until you
# fix it.

# %%
import warnings
warnings.filterwarnings("ignore")

WANDB_ENABLED = False
WANDB_PROJECT = "intro-tensorflow-Thomas_Odongo"  #changed to my  name

try:
    import wandb
    from wandb.integration.keras import WandbMetricsLogger
    logged_in = False

    # --- Uncomment once your WANDB_API_KEY secret is set, then re-run this cell ---

    from google.colab import userdata
    wandb.login(key=userdata.get("WANDB_API_KEY"))
    logged_in = True

    WANDB_ENABLED = logged_in
    if WANDB_ENABLED:
        print("W&B ready. Runs will be logged to project:", WANDB_PROJECT)
    else:
        print("W&B installed but not logged in yet -- uncomment the block above.")
        print("Until then, the notebook still runs, but NOTHING is being tracked.")
except Exception as e:
    print("W&B not available -- runs will NOT be logged until you fix this.")
    print("Reason:", e)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: t-odongo (t-odongo-african-leadership-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# W&B ready. Runs will be logged to project: intro-tensorflow-Thomas_Odongo

# %% [markdown]
# ## Step 4: One reusable function — `log_experiment()`
#
# Same idea as `train_and_evaluate()` from Parts 1 and 2, extended to
# also log to W&B. The important addition is `WandbMetricsLogger()`,
# passed straight into `model.fit(...)` as a callback — it logs
# **train loss, train accuracy, validation loss, and validation
# accuracy at the end of every single epoch**, live, while training is
# still running. That's the actual training loop, not just a summary
# of how it ended.
#
# On top of that per-epoch stream, we also log one summary (final
# metrics + a learning-curve plot) once training finishes, and keep a
# local record for the results table in Step 7. Every model from here
# on goes through this one function.
#
# 📖 [WandbMetricsLogger docs](https://docs.wandb.ai/guides/integrations/keras/#track-experiments-with-wandbmetricslogger)

# %%
RANDOM_STATE = 42
results_log = []  # every experiment's summary lands here -> becomes your results table in Step 7

def log_experiment(
    run_name: str,
    model: keras.Model,
    config: Dict[str, Any],
    X_train: np.ndarray,
    y_train: np.ndarray,
    epochs: int = 30,
    batch_size: int = 128,
) -> Any:
    # Assumes `model` is already compiled. Trains with a 10% validation
    # split and early stopping, logs every epoch to W&B, and records a
    # results_log row at the end.
    #
    # run_name : short descriptive string, e.g. "dense64_dropout0.2"
    # config   : dict of whatever you want tracked, e.g. {"architecture": "Sequential", "dropout": 0.2}
    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_accuracy", patience=3, restore_best_weights=True
    )

    callbacks = [early_stopping]
    run = None
    if WANDB_ENABLED:
        try:
            # wandb.init() has to happen BEFORE fit() -- WandbMetricsLogger
            # attaches to whichever run is currently active.
            run = wandb.init(project=WANDB_PROJECT, name=run_name, config=config, reinit=True)
            callbacks.append(WandbMetricsLogger())  # logs loss/accuracy + val_loss/val_accuracy every epoch
        except Exception as e:
            print(f"  (W&B run could not start: {e} -- continuing without live logging)")
            run = None

    history = model.fit(
        X_train, y_train,
        validation_split=0.1, epochs=epochs, batch_size=batch_size,
        callbacks=callbacks, verbose=0,
    )

    final_train_acc = history.history["accuracy"][-1]
    final_val_acc = history.history["val_accuracy"][-1]
    print(f"[{run_name}] train acc = {final_train_acc:.4f}, val acc = {final_val_acc:.4f}")

    if run is not None:
        try:
            fig, ax = plt.subplots(figsize=(5, 4))
            ax.plot(history.history["accuracy"], label="train")
            ax.plot(history.history["val_accuracy"], label="val")
            ax.set_xlabel("Epoch"); ax.set_ylabel("Accuracy"); ax.set_title(run_name); ax.legend()

            wandb.log({
                "final_train_accuracy": final_train_acc,
                "final_val_accuracy": final_val_acc,
                "epochs_run": len(history.history["loss"]),
                "learning_curve": wandb.Image(fig),
            })
            plt.close(fig)
        except Exception as e:
            print(f"  (W&B summary logging failed: {e})")
        finally:
            run.finish()

    results_log.append({
        "run_name": run_name,
        **config,
        "final_train_accuracy": round(final_train_acc, 4),
        "final_val_accuracy": round(final_val_acc, 4),
    })
    return model, history

# %% [markdown]
# ## Step 5: Baseline model
#
# A small, unremarkable Sequential model -- fully worked, no
# `<FILL_IN>` -- so you have a working, fully-tracked pipeline confirmed
# end-to-end, and a concrete number to beat before building anything
# fancier.
#
# Once this cell finishes, open the run link W&B prints and check the
# **charts tab** — you should see train/val loss and train/val accuracy
# plotted epoch by epoch, updated live while it trained, not just a
# single final number.

# %%
baseline_model = keras.Sequential([
    layers.Dense(64, activation="relu", input_shape=(784,)),
    layers.Dense(10, activation="softmax"),
])
baseline_model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

baseline_model, baseline_history = log_experiment(
    run_name="baseline-dense64",
    model=baseline_model,
    config={"architecture": "Sequential", "hidden_units": 64, "dropout": None},
    X_train=X_train, y_train=y_train,
)
# Out:
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/wandb/run-20260918_200713-c8bjo37g</code>
# Syncing run <strong><a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/c8bjo37g' target="_blank">baseline-dense64</a></strong> to <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo</a>
#  View run at <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/c8bjo37g' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/c8bjo37g</a>
# [baseline-dense64] train acc = 0.9946, val acc = 0.9763
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▅▅▆▆▇▇▇▇▇▇███████</td></tr><tr><td>epoch/epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▄▅▆▇▇▇▇▇▇▇███████</td></tr><tr><td>epoch/val_loss</td><td>█▅▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epochs_run</td><td>▁</td></tr><tr><td>final_train_accuracy</td><td>▁</td></tr><tr><td>final_val_accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.99459</td></tr><tr><td>epoch/epoch</td><td>17</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.02509</td></tr><tr><td>epoch/val_accuracy</td><td>0.97633</td></tr><tr><td>epoch/val_loss</td><td>0.09896</td></tr><tr><td>epochs_run</td><td>18</td></tr><tr><td>final_train_accuracy</td><td>0.99459</td></tr><tr><td>final_val_accuracy</td><td>0.97633</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">baseline-dense64</strong> at: <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/c8bjo37g' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/c8bjo37g</a><br> View project at: <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260918_200713-c8bjo37g/logs</code>

# %% [markdown]
# ## Step 6: Your models
#
# Your turn, no scaffolding: build at least two more models that beat
# the baseline, using anything from Parts 1-2 -- Sequential or
# Functional, Dropout, different widths or depths, more epochs. Reuse
# `log_experiment(...)` for every one, with a descriptive `run_name`
# and a `config` dict describing what's different about that run.

# %%
# Model 1: Wider Sequential Network with Dropout Regularization

model_wide = keras.Sequential([
    layers.Dense(128, activation="relu", input_shape=(784,)),
    layers.Dropout(0.2), # Limits overfitting by randomly muting 20% of neurons
    layers.Dense(10, activation="softmax"),
])

model_wide.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model_wide, history_wide = log_experiment(
    run_name="sequential-wide-dropout",
    model=model_wide,
    config={"architecture": "Sequential", "hidden_units": 128, "dropout": 0.2},
    X_train=X_train,
    y_train=y_train,
)


# Model 2: Non-Linear Parallel Branching Network (Functional API)

image_input = keras.Input(shape=(784,))

# Define parallel branches splitting off the same input
wide_path = layers.Dense(128, activation="relu")(image_input)
narrow_path = layers.Dense(16, activation="relu")(image_input)

# Fuse branches side-by-side
fused_features = layers.Concatenate()([wide_path, narrow_path])
outputs = layers.Dense(10, activation="softmax")(fused_features)

model_branching = keras.Model(inputs=image_input, outputs=outputs)

model_branching.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model_branching, history_branching = log_experiment(
    run_name="functional-parallel-branching",
    model=model_branching,
    config={"architecture": "Functional Branching", "hidden_units": 144, "dropout": None},
    X_train=X_train,
    y_train=y_train,
)
# Out:
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/wandb/run-20260918_200847-f4n0j2x8</code>
# Syncing run <strong><a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/f4n0j2x8' target="_blank">sequential-wide-dropout</a></strong> to <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo</a>
#  View run at <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/f4n0j2x8' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/f4n0j2x8</a>
# [sequential-wide-dropout] train acc = 0.9825, val acc = 0.9807
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▅▆▇▇▇█████</td></tr><tr><td>epoch/epoch</td><td>▁▂▂▃▄▅▅▆▇▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▄▃▂▂▂▁▁▁▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▃▅▆▆▆▇██▇█</td></tr><tr><td>epoch/val_loss</td><td>█▅▄▃▂▂▂▁▁▁▁</td></tr><tr><td>epochs_run</td><td>▁</td></tr><tr><td>final_train_accuracy</td><td>▁</td></tr><tr><td>final_val_accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.98248</td></tr><tr><td>epoch/epoch</td><td>10</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.05703</td></tr><tr><td>epoch/val_accuracy</td><td>0.98067</td></tr><tr><td>epoch/val_loss</td><td>0.06244</td></tr><tr><td>epochs_run</td><td>11</td></tr><tr><td>final_train_accuracy</td><td>0.98248</td></tr><tr><td>final_val_accuracy</td><td>0.98067</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sequential-wide-dropout</strong> at: <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/f4n0j2x8' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/f4n0j2x8</a><br> View project at: <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260918_200847-f4n0j2x8/logs</code>
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/wandb/run-20260918_200908-h593tnhf</code>
# Syncing run <strong><a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/h593tnhf' target="_blank">functional-parallel-branching</a></strong> to <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo</a>
#  View run at <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/h593tnhf' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/h593tnhf</a>
# [functional-parallel-branching] train acc = 0.9946, val acc = 0.9770
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▅▆▆▇▇▇████</td></tr><tr><td>epoch/epoch</td><td>▁▂▂▃▄▅▅▆▇▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▄▃▂▂▂▂▁▁▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▄▅▆▇▇▇████</td></tr><tr><td>epoch/val_loss</td><td>█▅▃▂▂▁▁▁▁▁▁</td></tr><tr><td>epochs_run</td><td>▁</td></tr><tr><td>final_train_accuracy</td><td>▁</td></tr><tr><td>final_val_accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.99463</td></tr><tr><td>epoch/epoch</td><td>10</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.02451</td></tr><tr><td>epoch/val_accuracy</td><td>0.977</td></tr><tr><td>epoch/val_loss</td><td>0.08364</td></tr><tr><td>epochs_run</td><td>11</td></tr><tr><td>final_train_accuracy</td><td>0.99463</td></tr><tr><td>final_val_accuracy</td><td>0.977</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">functional-parallel-branching</strong> at: <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/h593tnhf' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo/runs/h593tnhf</a><br> View project at: <a href='https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo' target="_blank">https://wandb.ai/t-odongo-african-leadership-university/intro-tensorflow-Thomas_Odongo</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260918_200908-h593tnhf/logs</code>

# %% [markdown]
# ## Step 7: Results table
#
# Auto-built from everything logged via `log_experiment(...)` above.

# %%
results_df = pd.DataFrame(results_log)
results_df
# Out:
#                         run_name          architecture  hidden_units  dropout  \
# 0               baseline-dense64            Sequential            64      NaN
# 1        sequential-wide-dropout            Sequential           128      0.2
# 2  functional-parallel-branching  Functional Branching           144      NaN
#
#    final_train_accuracy  final_val_accuracy
# 0                0.9946              0.9763
# 1                0.9825              0.9807
# 2                0.9946              0.9770

# %% [markdown]
# ## Step 8: Final check — the test set
#
# Every result so far is validation accuracy. Pick your best run from
# the table above and check it against the true test set -- untouched
# until now -- for one honest final number.

# %%
best_model = baseline_model  # <-- replace with your actual best model once you have one
test_loss, test_accuracy = best_model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Test accuracy: 0.9716

# %% [markdown]
# ## Wrap-up
#
# **Final question:** Looking at your results table and W&B dashboard,
# which change moved validation accuracy the most, and which moved it
# the least (or hurt it)? Reference specific run names.
#
# _Write your answer here:_ The change that moved validation accuracy the most was increasing layer capacity in sequential-wide-dropout, while omitting dropout entirely in baseline-dense64 moved it the least by letting it overfit
